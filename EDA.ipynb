# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
import pandas as pd
import numpy as np

# %%
# Plot
file_name = 'df_cleaned.pkl'

df_cleaned = pd.read_pickle(file_name)
piv = df_cleaned.pivot_table(index=['yyyymmdd'], columns=['stno'], values=['TX01'])

# Plot

plt.plot(piv)

# Labelling 

plt.xlabel("Date")
plt.ylabel("TX01")
plt.title("TX01 Time Series Plot")

# Display
plt.rcParams["figure.figsize"] = (100,3)
plt.legend(piv.columns, title=piv.columns.name)
plt.show()

# %% [markdown]
# Groupby date (`yyyymmdd`) to visualize

# %%
df_mean = df_cleaned.groupby(['yyyymmdd'])['TX01', 'PP01', 'WD01', 'WD02', 'PS01'].mean()
# Out:
# /tmp/ipykernel_12521/3113374775.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_mean = df_cleaned.groupby(['yyyymmdd'])['TX01', 'PP01', 'WD01', 'WD02', 'PS01'].mean()

# %%
def plot_mean(y):
    # Plot
    fig, ax = plt.subplots(1, 1, figsize = (100,3))

    plt.plot(df_mean[y])

    # Labelling 
    step = 1
    ax.xaxis.set_major_locator(md.YearLocator(step, month = 1, day = 1))
    ax.xaxis.set_major_formatter(md.DateFormatter('%Y'))

    plt.xticks(rotation=45)
    plt.xlabel("Date")
    plt.ylabel(y)
    plt.title(y + "Time Series Plot")

    # Display
    plt.show()

# %%
for y in ['TX01', 'PP01', 'WD01', 'WD02', 'PS01']:
    plot_mean(y)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:362, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:570, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: PP01
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:644, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     643 try:
# --> 644     parsed, reso = self._parse_with_reso(key)
#     645 except ValueError as err:
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexes/datetimelike.py:231, in DatetimeIndexOpsMixin._parse_with_reso(self, label)
#     229 def _parse_with_reso(self, label: str):
#     230     # overridden by TimedeltaIndex
# --> 231     parsed, reso_str = parsing.parse_time_string(label, self.freq)
#     232     reso = Resolution.from_attrname(reso_str)
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:321, in pandas._libs.tslibs.parsing.parse_time_string()
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:367, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# DateParseError: Unknown datetime string format, unable to parse: PP01
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /data1/home/hsnutardis/RCEC_summer_2022/EDA.ipynb Cell 8 in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2B140.109.172.135/data1/home/hsnutardis/RCEC_summer_2022/EDA.ipynb#ch0000007vscode-remote?line=3'>4</a> df_cleaned = pd.read_pickle(file_name)
#       <a href='vscode-notebook-cell://ssh-remote%2B140.109.172.135/data1/home/hsnutardis/RCEC_summer_2022/EDA.ipynb#ch0000007vscode-remote?line=4'>5</a> piv = df_cleaned.pivot_table(index=['yyyymmdd'], columns=['stno'], values=['PP01'])
# ----> <a href='vscode-notebook-cell://ssh-remote%2B140.109.172.135/data1/home/hsnutardis/RCEC_summer_2022/EDA.ipynb#ch0000007vscode-remote?line=5'>6</a> piv.loc[('PP01',467270)]
#       <a href='vscode-notebook-cell://ssh-remote%2B140.109.172.135/data1/home/hsnutardis/RCEC_summer_2022/EDA.ipynb#ch0000007vscode-remote?line=7'>8</a> # Plot
#      <a href='vscode-notebook-cell://ssh-remote%2B140.109.172.135/data1/home/hsnutardis/RCEC_summer_2022/EDA.ipynb#ch0000007vscode-remote?line=9'>10</a> plt.plot(piv)
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexing.py:1140, in _LocIndexer._getitem_tuple(self, tup)
#    1138 with suppress(IndexingError):
#    1139     tup = self._expand_ellipsis(tup)
# -> 1140     return self._getitem_lowerdim(tup)
#    1142 # no multi-index, so validate all of the indexers
#    1143 tup = self._validate_tuple_indexer(tup)
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexing.py:867, in _LocationIndexer._getitem_lowerdim(self, tup)
#     863 for i, key in enumerate(tup):
#     864     if is_label_like(key):
#     865         # We don't need to check for tuples here because those are
#     866         #  caught by the _is_nested_tuple_indexer check above.
# --> 867         section = self._getitem_axis(key, axis=i)
#     869         # We should never have a scalar section here, because
#     870         #  _getitem_lowerdim is only called after a check for
#     871         #  is_scalar_access, which that would be.
#     872         if section.ndim == self.ndim:
#     873             # we're in the middle of slicing through a MultiIndex
#     874             # revise the key wrt to `section` by inserting an _NS
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# -> 1153     return self.obj.xs(label, axis=axis)
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/generic.py:3864, in NDFrame.xs(self, key, axis, level, drop_level)
#    3862             new_index = index[loc]
#    3863 else:
# -> 3864     loc = index.get_loc(key)
#    3866     if isinstance(loc, np.ndarray):
#    3867         if loc.dtype == np.bool_:
#
# File ~/anaconda3/envs/RCEC_summer_2022/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:646, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     644     parsed, reso = self._parse_with_reso(key)
#     645 except ValueError as err:
# --> 646     raise KeyError(key) from err
#     648 if self._can_partial_date_slice(reso):
#     649     try:
#
# KeyError: 'PP01'
